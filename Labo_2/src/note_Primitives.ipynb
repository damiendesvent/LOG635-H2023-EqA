# %% [markdown]
# iamge 1 : ![image.png](attachment:image.png)

# %% [markdown]
#     area    extent  eccentricity  perimeter_area_ratio  ...  moments_central-2-0  moments_central-2-2  moments_hu-2  moments_hu-6
# 0    1.0  1.000000      0.000000              0.000000  ...             0.000000         0.000000e+00      0.000000  0.000000e+00
# 1  816.0  0.510000      0.473491              0.438001  ...        104125.289216         1.508338e+07      0.000763 -1.550202e-07
# 2    7.0  0.777778      0.377964              0.975490  ...             3.428571         1.183673e+00      0.000803  0.000000e+00
# 3    8.0  0.888889      0.612372              0.926777  ...             4.875000         2.587891e+00      0.000483  0.000000e+00
# 4    8.0  0.666667      0.577350              0.957107  ...             4.000000         1.000000e+00      0.000000  0.000000e+00
#
# [5 rows x 20 columns]

# %% [markdown]
# Pour l'extraction des primitives, nous avons utiliser "skimage" avec les "region properties". Mais avant de pouvoir

# %% [markdown]
# ![image.png](attachment:image.png)![image.png](attachment:image-2.png)![image.png](attachment:image-3.png)
